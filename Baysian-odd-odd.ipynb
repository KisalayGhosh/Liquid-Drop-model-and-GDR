# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
pip install mendeleev
# Out:
# Collecting mendeleev
#   Downloading mendeleev-0.14.0-py3-none-any.whl (353 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 353.1/353.1 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: Pygments<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from mendeleev) (2.14.0)
# Requirement already satisfied: SQLAlchemy>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from mendeleev) (2.0.16)
# Collecting colorama<0.5.0,>=0.4.4 (from mendeleev)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: numpy<2.0,>=1.21 in /usr/local/lib/python3.10/dist-packages (from mendeleev) (1.22.4)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from mendeleev) (1.5.3)
# Collecting pyfiglet<0.9,>=0.8.post1 (from mendeleev)
#   Downloading pyfiglet-0.8.post1-py2.py3-none-any.whl (865 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.8/865.8 kB 33.1 MB/s eta 0:00:00
# Requirement already satisfied: six<2.0.0,>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from mendeleev) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->mendeleev) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->mendeleev) (2022.7.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.4.0->mendeleev) (4.6.3)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.4.0->mendeleev) (2.0.2)
# Installing collected packages: pyfiglet, colorama, mendeleev
# Successfully installed colorama-0.4.6 mendeleev-0.14.0 pyfiglet-0.8.post1

# %%
pip install bilby
# Out:
# Collecting bilby
#   Downloading bilby-2.1.1-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 24.9 MB/s eta 0:00:00
# Collecting bilby.cython>=0.3.0 (from bilby)
#   Downloading bilby.cython-0.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 61.9 MB/s eta 0:00:00
# Collecting dynesty>=2.0.1 (from bilby)
#   Downloading dynesty-2.1.2-py2.py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 9.6 MB/s eta 0:00:00
# Collecting emcee (from bilby)
#   Downloading emcee-3.1.4-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 4.5 MB/s eta 0:00:00
# Collecting corner (from bilby)
#   Downloading corner-2.2.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bilby) (1.22.4)
# Requirement already satisfied: matplotlib>=2.1 in /usr/local/lib/python3.10/dist-packages (from bilby) (3.7.1)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.10/dist-packages (from bilby) (1.10.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from bilby) (1.5.3)
# Collecting dill (from bilby)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 12.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from bilby) (4.65.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from bilby) (3.8.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from bilby) (23.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->bilby) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->bilby) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->bilby) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->bilby) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->bilby) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->bilby) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->bilby) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->bilby) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->bilby) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1->bilby) (1.16.0)
# Installing collected packages: dynesty, emcee, dill, bilby.cython, corner, bilby
# Successfully installed bilby-2.1.1 bilby.cython-0.4.2 corner-2.2.2 dill-0.3.6 dynesty-2.1.2 emcee-3.1.4

# %%
pip install pymultinest==2.11
# Out:
# Collecting pymultinest==2.11
#   Downloading pymultinest-2.11-py2.py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: pymultinest
# Successfully installed pymultinest-2.11

# %%
pip install juliet
# Out:
# Collecting juliet
#   Downloading juliet-2.2.1-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.4/52.4 kB 2.0 MB/s eta 0:00:00
# Collecting batman-package (from juliet)
#   Downloading batman-package-2.4.9.tar.gz (394 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.8/394.8 kB 10.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting radvel (from juliet)
#   Downloading radvel-1.4.9.tar.gz (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: dynesty>=1.2.2 in /usr/local/lib/python3.10/dist-packages (from juliet) (2.1.2)
# Collecting george (from juliet)
#   Downloading george-0.4.0.tar.gz (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 9.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting celerite (from juliet)
#   Downloading celerite-0.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 21.9 MB/s eta 0:00:00
# Requirement already satisfied: astropy in /usr/local/lib/python3.10/dist-packages (from juliet) (5.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from juliet) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from juliet) (1.10.1)
# Requirement already satisfied: emcee in /usr/local/lib/python3.10/dist-packages (from juliet) (3.1.4)
# Collecting ultranest (from juliet)
#   Downloading ultranest-3.6.1.tar.gz (21.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 68.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pyerfa>=2.0 in /usr/local/lib/python3.10/dist-packages (from astropy->juliet) (2.0.0.3)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.10/dist-packages (from astropy->juliet) (6.0)
# Requirement already satisfied: packaging>=19.0 in /usr/local/lib/python3.10/dist-packages (from astropy->juliet) (23.1)
# Requirement already satisfied: cython>=0.23 in /usr/local/lib/python3.10/dist-packages (from radvel->juliet) (0.29.35)
# Requirement already satisfied: matplotlib>=1.5.3 in /usr/local/lib/python3.10/dist-packages (from radvel->juliet) (3.7.1)
# Requirement already satisfied: corner>=2.0 in /usr/local/lib/python3.10/dist-packages (from radvel->juliet) (2.2.2)
# Requirement already satisfied: pandas>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from radvel->juliet) (1.5.3)
# Collecting nbsphinx>=0.3.3 (from radvel->juliet)
#   Downloading nbsphinx-0.9.2-py3-none-any.whl (30 kB)
# Requirement already satisfied: jupyter_client>=5.2.4 in /usr/local/lib/python3.10/dist-packages (from radvel->juliet) (6.1.12)
# Requirement already satisfied: ipykernel>=4.10.0 in /usr/local/lib/python3.10/dist-packages (from radvel->juliet) (5.5.6)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from radvel->juliet) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from radvel->juliet) (2.8.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from radvel->juliet) (0.3.6)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.10.0->radvel->juliet) (0.2.0)
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.10.0->radvel->juliet) (7.34.0)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.10.0->radvel->juliet) (5.7.1)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.10.0->radvel->juliet) (6.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->radvel->juliet) (2.1.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from jupyter_client>=5.2.4->radvel->juliet) (5.3.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.10/dist-packages (from jupyter_client>=5.2.4->radvel->juliet) (23.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5.3->radvel->juliet) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5.3->radvel->juliet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5.3->radvel->juliet) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5.3->radvel->juliet) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5.3->radvel->juliet) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5.3->radvel->juliet) (3.1.0)
# Requirement already satisfied: docutils in /usr/local/lib/python3.10/dist-packages (from nbsphinx>=0.3.3->radvel->juliet) (0.16)
# Requirement already satisfied: nbconvert!=5.4 in /usr/local/lib/python3.10/dist-packages (from nbsphinx>=0.3.3->radvel->juliet) (6.5.4)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from nbsphinx>=0.3.3->radvel->juliet) (5.9.0)
# Requirement already satisfied: sphinx>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbsphinx>=0.3.3->radvel->juliet) (3.5.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.20.0->radvel->juliet) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.5.0->radvel->juliet) (1.16.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel>=4.10.0->radvel->juliet) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=5.0.0->ipykernel>=4.10.0->radvel->juliet)
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 55.7 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel>=4.10.0->radvel->juliet) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel>=4.10.0->radvel->juliet) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel>=4.10.0->radvel->juliet) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel>=4.10.0->radvel->juliet) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel>=4.10.0->radvel->juliet) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel>=4.10.0->radvel->juliet) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel>=4.10.0->radvel->juliet) (4.8.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.0->jupyter_client>=5.2.4->radvel->juliet) (3.7.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert!=5.4->nbsphinx>=0.3.3->radvel->juliet) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert!=5.4->nbsphinx>=0.3.3->radvel->juliet) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert!=5.4->nbsphinx>=0.3.3->radvel->juliet) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert!=5.4->nbsphinx>=0.3.3->radvel->juliet) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert!=5.4->nbsphinx>=0.3.3->radvel->juliet) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert!=5.4->nbsphinx>=0.3.3->radvel->juliet) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert!=5.4->nbsphinx>=0.3.3->radvel->juliet) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert!=5.4->nbsphinx>=0.3.3->radvel->juliet) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert!=5.4->nbsphinx>=0.3.3->radvel->juliet) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert!=5.4->nbsphinx>=0.3.3->radvel->juliet) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->nbsphinx>=0.3.3->radvel->juliet) (2.17.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->nbsphinx>=0.3.3->radvel->juliet) (4.3.3)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.8->nbsphinx>=0.3.3->radvel->juliet) (1.0.4)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.8->nbsphinx>=0.3.3->radvel->juliet) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.8->nbsphinx>=0.3.3->radvel->juliet) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.8->nbsphinx>=0.3.3->radvel->juliet) (2.0.1)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.8->nbsphinx>=0.3.3->radvel->juliet) (1.1.5)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.8->nbsphinx>=0.3.3->radvel->juliet) (1.0.3)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.8->nbsphinx>=0.3.3->radvel->juliet) (2.2.0)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.8->nbsphinx>=0.3.3->radvel->juliet) (2.12.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.8->nbsphinx>=0.3.3->radvel->juliet) (0.7.13)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.8->nbsphinx>=0.3.3->radvel->juliet) (1.4.1)
# Requirement already satisfied: requests>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.8->nbsphinx>=0.3.3->radvel->juliet) (2.27.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel>=4.10.0->radvel->juliet) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx>=0.3.3->radvel->juliet) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx>=0.3.3->radvel->juliet) (0.19.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=5.0.0->ipykernel>=4.10.0->radvel->juliet) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel>=4.10.0->radvel->juliet) (0.2.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx>=1.8->nbsphinx>=0.3.3->radvel->juliet) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx>=1.8->nbsphinx>=0.3.3->radvel->juliet) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx>=1.8->nbsphinx>=0.3.3->radvel->juliet) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx>=1.8->nbsphinx>=0.3.3->radvel->juliet) (3.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert!=5.4->nbsphinx>=0.3.3->radvel->juliet) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert!=5.4->nbsphinx>=0.3.3->radvel->juliet) (0.5.1)
# Building wheels for collected packages: batman-package, george, radvel, ultranest
#   Building wheel for batman-package (pyproject.toml) ... done
#   Created wheel for batman-package: filename=batman_package-2.4.9-cp310-cp310-linux_x86_64.whl size=229430 sha256=9f6e101ba5ad5603951f53c68cedf6abf8077fa40d69f32d4509cc0979825694
#   Stored in directory: /root/.cache/pip/wheels/d4/29/f5/245cad7bd7dcb2d11fb9fb1e76a0862145bbaf7731ef9e379e
#   Building wheel for george (pyproject.toml) ... done
#   Created wheel for george: filename=george-0.4.0-cp310-cp310-linux_x86_64.whl size=347809 sha256=08843fa3804695e46a00d2711d7df424ca9a7a083d9763ea1940c1efdb5d6068
#   Stored in directory: /root/.cache/pip/wheels/63/02/e3/24f2361717de09616769d97ed5854b4703d4df49fb1a3a1131
#   Building wheel for radvel (setup.py) ... done
#   Created wheel for radvel: filename=radvel-1.4.9-cp310-cp310-linux_x86_64.whl size=436177 sha256=d57ce3c4a397ce23e53ccaa236349d566e8d301379b2d53fde6edd9529c666cb
#   Stored in directory: /root/.cache/pip/wheels/1c/71/85/f545c79389d76eb22b04ba32b688ff2681aa91c134bcd7ab68
#   Building wheel for ultranest (pyproject.toml) ... done
#   Created wheel for ultranest: filename=ultranest-3.6.1-cp310-cp310-linux_x86_64.whl size=1946154 sha256=9da5852cecc884e9d2ccebf54850576a031782f199dcb4a3784edcca17b0c8a2
#   Stored in directory: /root/.cache/pip/wheels/8a/c2/a0/0d2eb115ffd5d1967be84bc577fd669228d5077840210db1cc
# Successfully built batman-package george radvel ultranest
# Installing collected packages: jedi, celerite, batman-package, george, ultranest, nbsphinx, radvel, juliet
# Successfully installed batman-package-2.4.9 celerite-0.4.2 george-0.4.0 jedi-0.18.2 juliet-2.2.1 nbsphinx-0.9.2 radvel-1.4.9 ultranest-3.6.1

# %%
import math
import sys
import numpy as np
import pandas as pd
from numpy import linspace, arange, zeros
from matplotlib.pylab import plt
from mendeleev import element
from bilby import result
import bilby
import seaborn as sns

# %%
label = 'ldm'
outdir = 'outdir'
bilby.utils.check_directory_exists_and_if_not_mkdir(outdir)

# %%
Z, N, BE_EXP = np.loadtxt('odd-odd.dat',usecols=(0,1,2), unpack= True)
A = Z + N
az = np.vstack((A,Z))
x = az

data = -BE_EXP
ndata = len(data)
P = open('results.out','w')
print('ndata=',ndata, file=P)

# %%
def model(az,a_v,a_s,a_a,a_c,a_p):
    a=az[0,:]
    z=az[1,:]
    a13 = pow(a,0.3333)
    zz1 = z*z
    nz = a -2*z
    nz2 = pow(nz , 2.0)
    a_p=(-34)


    BE=  a_v*a + a_s*a**(2.0/3.0)+ a_c*zz1/a13 + a_a*(nz2/a)-a_p*a**(-0.75)
    return BE

# %%
injection_parameters = dict(a_v=-14, a_s=18, a_a=23, a_c=0.7, a_p=(-34))
n = len(Z)
sigma = np.random.normal(1, 0.01, n)
sigma = 3.075

# %%
likelihood = bilby.likelihood.GaussianLikelihood(az, data, model,
sigma)

# %%
priors = dict()
priors['a_v'] = bilby.core.prior.Uniform(-30,-10 , '$a_v$',unit='MeV')
priors['a_s'] = bilby.core.prior.Uniform(0,25, '$a_s$',unit='MeV')
priors['a_a'] = bilby.core.prior.Uniform(15, 50, '$a_a$',unit='MeV')
priors['a_c'] = bilby.core.prior.Uniform(1,5,'$a_c$',unit='MeV')
priors['a_p'] = bilby.core.prior.Uniform(20,34,'$a_p$', unit='MeV' )
#priors['a_p'] = bilby.core.prior.Normal(34,5,'$a_p$', unit='MeV' )

# %%
result = bilby.run_sampler(
    likelihood=likelihood, priors=priors, sampler='dynesty', nlive=500,
    sample='unif', injection_parameters=injection_parameters, outdir=outdir,
    label=label)
result.plot_corner(priors=True,label_kwargs={"fontsize": 25},title_kwargs=dict(fontsize=20),max_n_ticks=3,smooth=1.0)
result.plot_marginals()
print( result.log_evidence, result.log_evidence_err,
            np.log(result.occam_factor(priors)))
# Out:
# 07:48 bilby INFO    : Running for label 'ldm', output will be saved to 'outdir'
# /usr/local/lib/python3.10/dist-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# 07:48 bilby INFO    : Analysis priors:
# 07:48 bilby INFO    : a_v=Uniform(minimum=-30, maximum=-10, name='$a_v$', latex_label='$a_v$', unit='MeV', boundary=None)
# 07:48 bilby INFO    : a_s=Uniform(minimum=0, maximum=25, name='$a_s$', latex_label='$a_s$', unit='MeV', boundary=None)
# 07:48 bilby INFO    : a_a=Uniform(minimum=15, maximum=50, name='$a_a$', latex_label='$a_a$', unit='MeV', boundary=None)
# 07:48 bilby INFO    : a_c=Uniform(minimum=1, maximum=5, name='$a_c$', latex_label='$a_c$', unit='MeV', boundary=None)
# 07:48 bilby INFO    : a_p=Uniform(minimum=20, maximum=34, name='$a_p$', latex_label='$a_p$', unit='MeV', boundary=None)
# 07:48 bilby INFO    : Analysis likelihood class: <class 'bilby.core.likelihood.GaussianLikelihood'>
# 07:48 bilby INFO    : Analysis likelihood noise evidence: nan
# 07:48 bilby INFO    : Single likelihood evaluation took 2.855e-04 s
# 07:48 bilby INFO    : Using sampler Dynesty with kwargs {'nlive': 500, 'bound': 'live', 'sample': 'unif', 'periodic': None, 'reflective': None, 'update_interval': 600, 'first_update': None, 'npdim': None, 'rstate': None, 'queue_size': 1, 'pool': None, 'use_pool': None, 'live_points': None, 'logl_args': None, 'logl_kwargs': None, 'ptform_args': None, 'ptform_kwargs': None, 'gradient': None, 'grad_args': None, 'grad_kwargs': None, 'compute_jac': False, 'enlarge': None, 'bootstrap': None, 'walks': 100, 'facc': 0.2, 'slices': None, 'fmove': 0.9, 'max_move': 100, 'update_func': None, 'ncdim': None, 'blob': False, 'save_history': False, 'history_filename': None, 'maxiter': None, 'maxcall': None, 'dlogz': 0.1, 'logl_max': inf, 'n_effective': None, 'add_live': True, 'print_progress': True, 'print_func': <bound method Dynesty._print_func of <bilby.core.sampler.dynesty.Dynesty object at 0x7fea55f5e4d0>>, 'save_bounds': False, 'checkpoint_file': None, 'checkpoint_every': 60, 'resume': False}
# 07:48 bilby INFO    : Checkpoint every check_point_delta_t = 600s
# 07:48 bilby INFO    : Using dynesty version 2.1.2
# 07:48 bilby INFO    : Live-point based bound method requested with dynesty sample 'unif', overwriting to 'multi'
# 07:48 bilby INFO    : Resume file outdir/ldm_resume.pickle does not exist.
# 07:48 bilby INFO    : Generating initial points from the prior
# 1it [00:00, ?it/s]
# 07:50 bilby INFO    : Written checkpoint file outdir/ldm_resume.pickle
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# /usr/local/lib/python3.10/dist-packages/dynesty/plotting.py:318: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 07:51 bilby INFO    : Rejection sampling nested samples to obtain 2164 posterior samples
# 07:51 bilby INFO    : Sampling time: 0:02:06.180883
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:241: RuntimeWarning: numpy.ndarray size changed, may indicate binary incompatibility. Expected 88 from C header, got 96 from PyObject
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# 07:51 bilby INFO    : Summary of results:
# nsamples: 2164
# ln_noise_evidence:    nan
# ln_evidence: -25073.045 +/-  0.330
# ln_bayes_factor:    nan +/-  0.330
#
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:671: ImportWarning: _BokehImportHook.exec_module() not found; falling back to load_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# 07:51 bilby INFO    : Plotting a_v marginal distribution
# 07:51 bilby INFO    : Plotting a_v marginal distribution
# 07:51 bilby INFO    : Plotting a_s marginal distribution
# 07:51 bilby INFO    : Plotting a_s marginal distribution
# 07:51 bilby INFO    : Plotting a_a marginal distribution
# 07:51 bilby INFO    : Plotting a_a marginal distribution
# 07:51 bilby INFO    : Plotting a_c marginal distribution
# 07:51 bilby INFO    : Plotting a_c marginal distribution
# 07:51 bilby INFO    : Plotting a_p marginal distribution
# 07:51 bilby INFO    : Plotting a_p marginal distribution
# 07:51 bilby INFO    : Plotting log_likelihood marginal distribution
# 07:51 bilby INFO    : Plotting log_likelihood marginal distribution
# 07:51 bilby INFO    : Plotting log_prior marginal distribution
# 07:51 bilby INFO    : Plotting log_prior marginal distribution
# -25073.044904698378 0.3298816903093045 -55.375749675347514

# %%
av_fit=result.get_one_dimensional_median_and_error_bar('a_v')
av1 = av_fit.median
as_fit=result.get_one_dimensional_median_and_error_bar('a_s')
as1 = as_fit.median
aa_fit=result.get_one_dimensional_median_and_error_bar('a_a')
aa1 = aa_fit.median
ac_fit=result.get_one_dimensional_median_and_error_bar('a_c')
ac1 = ac_fit.median
ap_fit=result.get_one_dimensional_median_and_error_bar('a_p')
ap1 = ap_fit.median
print(av1,as1,aa1,ac1,ap1)
data_fit = model(az,av1,as1,aa1,ac1,ap1)
# Out:
# -18.87597044156548 24.999848208964792 30.20581932007503 1.0000026201499987 27.087711639207832

# %%
cov_mat = result.covariance_matrix
nrow,ncol=np.shape(cov_mat)
print('row and columns',nrow,ncol)
corr=np.empty((nrow,ncol))
for i in range(0,nrow):
    for j in range(0,ncol):
        corr[i][j]=cov_mat[i][j] /np.sqrt(cov_mat[i][i]*cov_mat[j][j])
#output=open('results.out','w')
np.set_printoptions(precision=3)
#print(corr,file=output)
#print('Correlationmatrix',file=P)
#print(corr,file=P)
#utput.close()
print(corr)
# Out:
# row and columns 5 5
# [[ 1.    -0.045 -0.903 -0.008  0.049]
#  [-0.045  1.     0.012 -0.07  -0.002]
#  [-0.903  0.012  1.     0.016 -0.023]
#  [-0.008 -0.07   0.016  1.    -0.006]
#  [ 0.049 -0.002 -0.023 -0.006  1.   ]]

# %%
print(corr)
# Out:
# [[ 1.    -0.045 -0.903 -0.008  0.049]
#  [-0.045  1.     0.012 -0.07  -0.002]
#  [-0.903  0.012  1.     0.016 -0.023]
#  [-0.008 -0.07   0.016  1.    -0.006]
#  [ 0.049 -0.002 -0.023 -0.006  1.   ]]

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
print('Parameters', file =P)
data1 = { 'av':[av_fit.median], 'plus':[av_fit.plus], 'minus':[av_fit.minus]}
data2 = { 'as':[as_fit.median], 'plus':[as_fit.plus], 'minus':[as_fit.minus]}
data3 = { 'aa':[aa_fit.median], 'plus':[aa_fit.plus], 'minus':[aa_fit.minus]}
data4 = { 'ac':[ac_fit.median], 'plus':[ac_fit.plus], 'minus':[ac_fit.minus]}
data5 = { 'ap':[ap_fit.median], 'plus':[ap_fit.plus], 'minus':[ap_fit.minus]}
df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)
df3 = pd.DataFrame(data3)
df4 = pd.DataFrame(data4)
df5 = pd.DataFrame(data5)
print(df1.to_string(index=False),file=P)
print(df2.to_string(index=False),file=P)
print(df3.to_string(index=False),file=P)
print(df4.to_string(index=False),file=P)
print(df5.to_string(index=False),file=P)
# Out:
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()

# %%
H=open('fit.out','w')

data6={'Z':Z, 'N':N, 'BE_EXP':BE_EXP, 'BE_FIT':data_fit}
df=pd.DataFrame(data6)
print(df.to_string(index=False),file=H)
H.close()

# %%
plt.plot(Z,-BE_EXP )
plt.plot(Z, data_fit)


plt.xlabel('Z Proton no')

plt.ylabel('BE')


plt.legend(["BE-EXP", "data-fit"], loc ="lower right")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# giving a title to my graph
plt.title('fit ')

# function to show the plot

plt.savefig('fit.png') #.format(outdir, label))

# %%
plt.show()
chisq = np.sum(((data-data_fit)/sigma)**2.0)
#J = open('chi.out','w')
data5={'Chi2=':[chisq]}
df5 = pd.DataFrame(data5)
print(df5.to_string(index=False),file=P)
#J.close()

P.close()
print ('chisq',chisq)
# Out:
# chisq 46436.01094510376
